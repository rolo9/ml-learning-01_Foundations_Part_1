# %% [markdown]
# # 最急降下法

# %% [markdown]
# ## データ準備

# %%
import pandas as pd
df = pd.read_csv('../data/sample_data.csv')

# %%
df
# Out:
#    space       rent
# 0     20  13.958824
# 1     25  11.533805
# 2     28  14.269547
# 3     30  18.722680
# 4     36  19.602674
# 5     51  16.068166
# 6     55  23.183599
# 7     62  22.212595
# 8     83  29.357010
# 9    103  37.565129

# %% [markdown]
# ## データの可視化

# %%
import seaborn as sns
